# %%
import random

# A list = collection of items stored in square brackets [ ]
archetypes = [
    "🌀 Red Dragon — Birth of Being, Nurture it",
    "🌬️ White Wind — Communication of Spirit through Breath",
    "🔥 Blue Night — Abundance of Intuition in Dreams",
    "🌱 Yellow Seed — Flowering through the Targeting of Awareness",
    "🐍 Red Serpent — Serpent of Instictive Life-Force",
    "⛩️ White Worldbridger — Equalization of Opportunity through Death",
    "✋ Blue Hand — Know Healing through Accomplishment",
    "🌞 Yellow Star — Beautify through the Elegance of Art",
    "🌙 Red Moon — Universal-Water Flowing to Purify",
    "🐶 White Dog — Loyalty of a Loving Heart",
    "🐒 Blue Monkey — Play with the Illusion with Magic",
    "🚶 Yellow Human — Free-Will to Influence with Wisdom",
    "🛸 Red Skywalker — Wakeful Exploration of Space",
    "🧙🏻 White Wizard — Receptive, Enchanting from Timelessness",
    "🦅 Blue Eagle — Create your Vision with your Mind",
    "💂 Yellow Warrior — Question with Intelligence and Fearlessness",
    "🌎 Red Earth — Evolve by Navigating Synchronically",
    "♾️ White Mirror — Endless Reflection of Order",
    "🌀 Blue Storm — Self-Generate by Catalizing Energy",
    "☀️ Yellow Sun — Enlighten Life with Universal-Fire"
]

def essence_oracle(name):
    return f"{name}, your current essence is: {random.choice(archetypes)}"

names = ["Serge", "Rene", "X", "Xoko"]

for person in names:
    print(essence_oracle(person))

# %%
import seaborn as sns
import pandas as pd

#Load dataset
titanic = sns.load_dataset("titanic")

#Preview first rows
titanic.head()

titanic.groupby(["class", "sex"])["survived"].mean().unstack().plot(
    kind="bar",
    figsize=(8,5),
    title="Survival Rate by Class and Sex"
)
# Out:
# /tmp/ipython-input-1371683234.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(["class", "sex"])["survived"].mean().unstack().plot(
# <Axes: title={'center': 'Survival Rate by Class and Sex'}, xlabel='class'>
